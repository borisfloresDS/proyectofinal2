# %% [markdown]
# ## 1. Configuraciones iniciales

# %%
import pandas as pd
import numpy as np
import boto3
import psycopg2
import configparser

# %% [markdown]
# ### 1.1 Leer archivo de configuración

# %%
config = configparser.ConfigParser()
config.read('config.cfg')
# Out:
# ['config.cfg']

# %% [markdown]
# ### 1.2 Acceder a base de datos transaccional

# %%
RDS_HOSTNAME = 'e-dreams-transactional.cfum2oeu0d6b.us-east-1.rds.amazonaws.com'

# %%
driver = f"""postgresql://{config.get('TRANSACC', 'DB_USER')}:{config.get('TRANSACC', 'DB_PASSWORD')}@{RDS_HOSTNAME}:{config.get('TRANSACC', 'DB_PORT')}/{config.get('TRANSACC', 'DB_NAME')}"""

# %% [markdown]
# ## 2. Crear las dimensiones

# %% [markdown]
# ### 2.1 Dimensión de artículos

# %% [markdown]
# #### 2.1.1 Tabla articulo

# %%
query = 'SELECT * FROM articulo;'
df_articulos = pd.read_sql(query, driver)
df_articulos
# Out:
#      id_articulo  id_categoria codigo     nombre  precio_venta  stock  \
# 0              0         10010  66883      among         58.97     61
# 1              1         10015  86212        run         94.42     38
# 2              2         10015  84042  agreement         93.58     48
# 3              3         10025  61637      treat         74.02     61
# 4              4         10025  40882      image         41.02     71
# ..           ...           ...    ...        ...           ...    ...
# 995          995         10018  36947     career         37.44     90
# 996          996         10008  74981    finally         45.04     27
# 997          997         10025  39489       nice         72.40     46
# 998          998         10025  27450    central         28.28      1
# 999          999         10010  29671     create         63.95     33
#
#                                            descripcion                imagen  \
# 0    Hotel off security design second. Born at cour...        Agree himself.
# 1    Entire air final because relationship. Minute ...  Check sense support.
# 2    Material appear there recognize. Level perhaps...    Enough avoid with.
# 3    Tax senior half marriage well. Thousand decide...             Positive.
# 4    Report strategy soldier prevent will executive...      Develop mention.
# ..                                                 ...                   ...
# 995  Ask garden method last than nothing suddenly a...    Protect want then.
# 996  Resource small prepare send stage church tradi...   Specific near land.
# 997  Evidence issue field subject seem film. Few to...  Loss yard once help.
# 998  Song minute sell identify focus among media. H...   Teach relationship.
# 999  Treatment else very. Under alone than against ...     Shoulder support.
#
#      estado_articulo
# 0              False
# 1               True
# 2              False
# 3               True
# 4              False
# ..               ...
# 995             True
# 996            False
# 997            False
# 998             True
# 999             True
#
# [1000 rows x 9 columns]

# %%
df_articulos = df_articulos.drop(columns=['stock', 'estado_articulo'])
df_articulos
# Out:
#      id_articulo  id_categoria codigo     nombre  precio_venta  \
# 0              0         10010  66883      among         58.97
# 1              1         10015  86212        run         94.42
# 2              2         10015  84042  agreement         93.58
# 3              3         10025  61637      treat         74.02
# 4              4         10025  40882      image         41.02
# ..           ...           ...    ...        ...           ...
# 995          995         10018  36947     career         37.44
# 996          996         10008  74981    finally         45.04
# 997          997         10025  39489       nice         72.40
# 998          998         10025  27450    central         28.28
# 999          999         10010  29671     create         63.95
#
#                                            descripcion                imagen
# 0    Hotel off security design second. Born at cour...        Agree himself.
# 1    Entire air final because relationship. Minute ...  Check sense support.
# 2    Material appear there recognize. Level perhaps...    Enough avoid with.
# 3    Tax senior half marriage well. Thousand decide...             Positive.
# 4    Report strategy soldier prevent will executive...      Develop mention.
# ..                                                 ...                   ...
# 995  Ask garden method last than nothing suddenly a...    Protect want then.
# 996  Resource small prepare send stage church tradi...   Specific near land.
# 997  Evidence issue field subject seem film. Few to...  Loss yard once help.
# 998  Song minute sell identify focus among media. H...   Teach relationship.
# 999  Treatment else very. Under alone than against ...     Shoulder support.
#
# [1000 rows x 7 columns]

# %% [markdown]
# #### 2.1.2 Tabla categoria

# %%
query = 'SELECT * FROM categoria;'
df_categoria = pd.read_sql(query, driver)
df_categoria
# Out:
#    id_categoria            nombre                   descripcion  \
# 0         10008       comestibles                        comida
# 1         10010  AlimentoMascotas                      Mascotas
# 2         10015         Golosinas            Chocolates, dulces
# 3         10018        MuebleCaja  articulos de muebles de caja
# 4         10025            gorros              gorros para frio
#
#    estado_categoria
# 0              True
# 1              True
# 2              True
# 3              True
# 4             False

# %%
df_categoria = df_categoria.drop(columns=['estado_categoria'])
df_categoria = df_categoria.rename(columns={'nombre': 'nombre_categoria', 'descripcion': 'descripcion_categoria'})
df_categoria
# Out:
#    id_categoria  nombre_categoria         descripcion_categoria
# 0         10008       comestibles                        comida
# 1         10010  AlimentoMascotas                      Mascotas
# 2         10015         Golosinas            Chocolates, dulces
# 3         10018        MuebleCaja  articulos de muebles de caja
# 4         10025            gorros              gorros para frio

# %% [markdown]
# #### 2.1.2 Crear la dimension

# %%
dim_articulo = df_articulos.merge(df_categoria, on='id_categoria', how='inner')
dim_articulo
# Out:
#      id_articulo  id_categoria codigo   nombre  precio_venta  \
# 0              0         10010  66883    among         58.97
# 1             12         10010  49381     lose         53.39
# 2             13         10010  16616     cell         82.76
# 3             14         10010  77174      son         30.26
# 4             16         10010  70720      off         94.47
# ..           ...           ...    ...      ...           ...
# 995          981         10008  11666     what         59.30
# 996          986         10008  36033     sort         40.34
# 997          990         10008  12349    whole         61.85
# 998          994         10008  15604    event         67.85
# 999          996         10008  74981  finally         45.04
#
#                                            descripcion                imagen  \
# 0    Hotel off security design second. Born at cour...        Agree himself.
# 1    Pressure report same president see young. Avoi...    Well realize fish.
# 2    Ball great matter. Plan national send room end...    Wonder discussion.
# 3    Back throughout what fly generation day. Thus ...   Method economy man.
# 4    Street home effort again news according. Bad s...  Including here city.
# ..                                                 ...                   ...
# 995  South bag entire message. Beautiful anything m...      Behavior record.
# 996  Themselves several society specific research. ...     Church seem with.
# 997  Whole age central PM police camera compare mee...      Next could talk.
# 998  Long series plant reveal natural collection li...    At trip test hard.
# 999  Resource small prepare send stage church tradi...   Specific near land.
#
#      nombre_categoria descripcion_categoria
# 0    AlimentoMascotas              Mascotas
# 1    AlimentoMascotas              Mascotas
# 2    AlimentoMascotas              Mascotas
# 3    AlimentoMascotas              Mascotas
# 4    AlimentoMascotas              Mascotas
# ..                ...                   ...
# 995       comestibles                comida
# 996       comestibles                comida
# 997       comestibles                comida
# 998       comestibles                comida
# 999       comestibles                comida
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### 2.2 Dimensión de personas

# %% [markdown]
# #### 2.2.1 Crear la dimension

# %%
query = 'SELECT * FROM persona;'
dim_personas = pd.read_sql(query, driver)
dim_personas
# Out:
#    id_persona tipo_persona            nombre tipo_documento num_documento  \
# 0           0     Juridica       Collin Pope       Licencia   892-95-2112
# 1           1   Individual     Joel Campbell       Licencia   704-56-0410
# 2           2     Juridica      Daniel Lopez            DPI   033-21-0987
# 3           3     Juridica    Melissa Larsen            DPI   402-40-5373
# 4           4     Juridica    Frank Martinez            DPI   233-12-7368
# 5           5     Juridica      Ashley Moore            DPI   280-16-3603
# 6           6   Individual    James Martinez            DPI   638-35-1288
# 7           7   Individual      Bryan Gibson       Licencia   130-85-6202
# 8           8     Juridica  Lauren Wells PhD       Licencia   354-29-0070
# 9           9   Individual  Brenda Stevenson            DPI   877-53-9451
#
#                direccion  telefono                 email
# 0  634 Benson Circle\nGr  90976019  brooksmaria@yahoo.co
# 1  7923 Carr Well\nLake   41255764  whitakerjennifer@gma
# 2   08455 Eric Hills Apt  66528770    urusso@hotmail.com
# 3   008 Kennedy Roads Ap  73762003  michelle89@gmail.com
# 4   2711 Reynolds Causew  25501899  josephadams@gmail.co
# 5  126 Beltran Parkway\n  89925465  gabriellathornton@gm
# 6  227 Sean Lane\nLake S  71380723    sharon24@gmail.com
# 7  PSC 2911, Box 2871\nA  73886843  christina98@gmail.co
# 8   66297 Beck Points Su  85580160  floresbrett@gmail.co
# 9  655 David Fall\nSouth  92796495    xjohnson@yahoo.com

# %% [markdown]
# ### 2.3 Dimensión de usuario

# %% [markdown]
# #### 2.3.1 Tabla usuario

# %%
query = 'SELECT * FROM usuario;'
df_usuario = pd.read_sql(query, driver)
df_usuario
# Out:
#       id_usuario  id_rol             nombre tipo_documento num_documento  \
# 0              0   14586      Jason Collins       Licencia   171-37-6240
# 1              1   14586       Kelly Nelson            DPI   317-88-6562
# 2              2   18568          Randy Lee       Licencia   872-50-5771
# 3              3   14586  Christopher Hardy            DPI   084-04-7482
# 4              4   16578         Jason West       Licencia   631-57-6208
# ...          ...     ...                ...            ...           ...
# 9995        9995   16578         Ann Martin            DPI   590-34-9478
# 9996        9996   16578        Rickey Cruz       Licencia   683-13-5659
# 9997        9997   14586     Hannah Sanchez       Licencia   681-85-8890
# 9998        9998   18568          Brian Orr       Licencia   846-47-3146
# 9999        9999   18568      Ashley Newman       Licencia   547-88-8870
#
#                   direccion  telefono                 email  \
# 0      167 Kim Mills Suite   66466083  josephaustin@gmail.c
# 1      55279 Gibson Forge S  22196109  cheryl25@hotmail.com
# 2      7265 Simmons Estate   41975722  ginarivers@yahoo.com
# 3     05077 Thomas Square\n  27287390    amanda48@gmail.com
# 4      1654 Adams Spring Ap  81139864  matthewcarr@yahoo.co
# ...                     ...       ...                   ...
# 9995  55399 Ryan Track\nDan  39241256  roachwendy@gmail.com
# 9996  799 Barnes Rue\nNorth  57820290   susan55@hotmail.com
# 9997  059 Patty Island\nWes  11249491     rmorgan@yahoo.com
# 9998  95472 Grimes Street\n  68817726  patriciabrown@yahoo.
# 9999   86952 Gomez Forks Ap  72085359   barry22@hotmail.com
#
#                                                   clave  estado_usuario
# 0     [b'x', b'6', b'3', b'n', b'F', b'V', b'T', b'y...           False
# 1     [b'&', b'A', b'J', b'd', b'9', b'O', b'k', b'L...            True
# 2     [b'X', b'B', b'7', b'q', b'R', b'r', b')', b'K...           False
# 3     [b')', b'm', b'6', b'5', b'7', b'v', b'a', b'p...           False
# 4     [b'Z', b'3', b'f', b'D', b'8', b'o', b'2', b'b...            True
# ...                                                 ...             ...
# 9995  [b'Z', b'v', b'I', b'R', b'g', b'T', b'1', b'X...            True
# 9996  [b'B', b'H', b'N', b'O', b'S', b'9', b'N', b'm...            True
# 9997  [b'!', b'e', b'6', b'7', b'R', b'd', b'h', b'B...           False
# 9998  [b'J', b'O', b'%', b'x', b'(', b'D', b'b', b'd...           False
# 9999  [b'_', b'6', b'^', b'Z', b'4', b'I', b'D', b'f...           False
#
# [10000 rows x 10 columns]

# %%
df_usuario = df_usuario.drop(columns=['estado_usuario'])
df_usuario
# Out:
#       id_usuario  id_rol             nombre tipo_documento num_documento  \
# 0              0   14586      Jason Collins       Licencia   171-37-6240
# 1              1   14586       Kelly Nelson            DPI   317-88-6562
# 2              2   18568          Randy Lee       Licencia   872-50-5771
# 3              3   14586  Christopher Hardy            DPI   084-04-7482
# 4              4   16578         Jason West       Licencia   631-57-6208
# ...          ...     ...                ...            ...           ...
# 9995        9995   16578         Ann Martin            DPI   590-34-9478
# 9996        9996   16578        Rickey Cruz       Licencia   683-13-5659
# 9997        9997   14586     Hannah Sanchez       Licencia   681-85-8890
# 9998        9998   18568          Brian Orr       Licencia   846-47-3146
# 9999        9999   18568      Ashley Newman       Licencia   547-88-8870
#
#                   direccion  telefono                 email  \
# 0      167 Kim Mills Suite   66466083  josephaustin@gmail.c
# 1      55279 Gibson Forge S  22196109  cheryl25@hotmail.com
# 2      7265 Simmons Estate   41975722  ginarivers@yahoo.com
# 3     05077 Thomas Square\n  27287390    amanda48@gmail.com
# 4      1654 Adams Spring Ap  81139864  matthewcarr@yahoo.co
# ...                     ...       ...                   ...
# 9995  55399 Ryan Track\nDan  39241256  roachwendy@gmail.com
# 9996  799 Barnes Rue\nNorth  57820290   susan55@hotmail.com
# 9997  059 Patty Island\nWes  11249491     rmorgan@yahoo.com
# 9998  95472 Grimes Street\n  68817726  patriciabrown@yahoo.
# 9999   86952 Gomez Forks Ap  72085359   barry22@hotmail.com
#
#                                                   clave
# 0     [b'x', b'6', b'3', b'n', b'F', b'V', b'T', b'y...
# 1     [b'&', b'A', b'J', b'd', b'9', b'O', b'k', b'L...
# 2     [b'X', b'B', b'7', b'q', b'R', b'r', b')', b'K...
# 3     [b')', b'm', b'6', b'5', b'7', b'v', b'a', b'p...
# 4     [b'Z', b'3', b'f', b'D', b'8', b'o', b'2', b'b...
# ...                                                 ...
# 9995  [b'Z', b'v', b'I', b'R', b'g', b'T', b'1', b'X...
# 9996  [b'B', b'H', b'N', b'O', b'S', b'9', b'N', b'm...
# 9997  [b'!', b'e', b'6', b'7', b'R', b'd', b'h', b'B...
# 9998  [b'J', b'O', b'%', b'x', b'(', b'D', b'b', b'd...
# 9999  [b'_', b'6', b'^', b'Z', b'4', b'I', b'D', b'f...
#
# [10000 rows x 9 columns]

# %% [markdown]
# #### 2.3.2 Tabla rol

# %%
query = 'SELECT * FROM rol;'
df_rol = pd.read_sql(query, driver)
df_rol
# Out:
#    id_rol         nombre    descripcion  estado_rol
# 0   14586        Gerente  Acceso maximo        True
# 1   18568  Administrador   Acceso medio        True
# 2   16578        Cliente  Acceso minimo        True

# %%
df_rol = df_rol.drop(columns=['estado_rol'])
df_rol = df_rol.rename(columns={'nombre': 'nombre_rol', 'descripcion': 'descripcion_rol'})
df_rol
# Out:
#    id_rol     nombre_rol descripcion_rol
# 0   14586        Gerente   Acceso maximo
# 1   18568  Administrador    Acceso medio
# 2   16578        Cliente   Acceso minimo

# %% [markdown]
# #### 2.3.3 Crear la dimension

# %%
dim_usuario = df_usuario.merge(df_rol, on='id_rol', how='inner')
dim_usuario
# Out:
#       id_usuario  id_rol             nombre tipo_documento num_documento  \
# 0              0   14586      Jason Collins       Licencia   171-37-6240
# 1              1   14586       Kelly Nelson            DPI   317-88-6562
# 2              3   14586  Christopher Hardy            DPI   084-04-7482
# 3              6   14586     Karen Martinez       Licencia   468-80-7914
# 4              7   14586      Marilyn Smith            DPI   393-69-7839
# ...          ...     ...                ...            ...           ...
# 9995        9984   16578    Angela Mitchell       Licencia   376-43-4261
# 9996        9987   16578      Kathryn Lopez       Licencia   177-53-2078
# 9997        9989   16578       Janet Kelley       Licencia   440-43-8139
# 9998        9995   16578         Ann Martin            DPI   590-34-9478
# 9999        9996   16578        Rickey Cruz       Licencia   683-13-5659
#
#                   direccion  telefono                 email  \
# 0      167 Kim Mills Suite   66466083  josephaustin@gmail.c
# 1      55279 Gibson Forge S  22196109  cheryl25@hotmail.com
# 2     05077 Thomas Square\n  27287390    amanda48@gmail.com
# 3      473 Jeffrey Road Sui  50765566      kyle37@gmail.com
# 4      8914 Matthew Straven  47257080  hannahherrera@hotmai
# ...                     ...       ...                   ...
# 9995   6838 Simon Expresswa  95455456     james52@yahoo.com
# 9996  9983 Hammond Mill\nSo  99755621  williammurray@hotmai
# 9997  8241 Maddox Spurs\nBr  52289217      hmyers@yahoo.com
# 9998  55399 Ryan Track\nDan  39241256  roachwendy@gmail.com
# 9999  799 Barnes Rue\nNorth  57820290   susan55@hotmail.com
#
#                                                   clave nombre_rol  \
# 0     [b'x', b'6', b'3', b'n', b'F', b'V', b'T', b'y...    Gerente
# 1     [b'&', b'A', b'J', b'd', b'9', b'O', b'k', b'L...    Gerente
# 2     [b')', b'm', b'6', b'5', b'7', b'v', b'a', b'p...    Gerente
# 3     [b'6', b'B', b'$', b'r', b'V', b'1', b'G', b'h...    Gerente
# 4     [b'u', b'*', b')', b'1', b'm', b'$', b'I', b'e...    Gerente
# ...                                                 ...        ...
# 9995  [b')', b'I', b'2', b'w', b'%', b'X', b'Y', b'o...    Cliente
# 9996  [b'(', b'W', b'f', b'j', b'j', b'f', b'C', b'+...    Cliente
# 9997  [b'I', b'8', b'I', b'r', b'Y', b'N', b'C', b'Z...    Cliente
# 9998  [b'Z', b'v', b'I', b'R', b'g', b'T', b'1', b'X...    Cliente
# 9999  [b'B', b'H', b'N', b'O', b'S', b'9', b'N', b'm...    Cliente
#
#      descripcion_rol
# 0      Acceso maximo
# 1      Acceso maximo
# 2      Acceso maximo
# 3      Acceso maximo
# 4      Acceso maximo
# ...              ...
# 9995   Acceso minimo
# 9996   Acceso minimo
# 9997   Acceso minimo
# 9998   Acceso minimo
# 9999   Acceso minimo
#
# [10000 rows x 11 columns]

# %% [markdown]
# ### 2.4 Dimensión de fecha

# %% [markdown]
# #### 2.4.1 Traer fechas de la tabla venta

# %%
query = 'SELECT fecha FROM venta;'
df_fecha_venta = pd.read_sql(query, driver)
df_fecha_venta
# Out:
#          fecha
# 0   2022-01-02
# 1   2024-02-06
# 2   2024-03-26
# 3   2022-01-29
# 4   2021-06-08
# ..         ...
# 995 2023-04-10
# 996 2021-12-19
# 997 2022-02-09
# 998 2020-05-22
# 999 2021-08-04
#
# [1000 rows x 1 columns]

# %% [markdown]
# #### 2.4.2 Traer fechas de la tabla ingreso

# %%
query = 'SELECT fecha FROM ingreso;'
df_fecha_ingreso = pd.read_sql(query, driver)
df_fecha_ingreso
# Out:
#          fecha
# 0   2020-02-13
# 1   2024-02-09
# 2   2022-05-17
# 3   2022-10-27
# 4   2022-12-21
# ..         ...
# 995 2023-12-16
# 996 2022-11-22
# 997 2022-08-04
# 998 2022-04-07
# 999 2022-08-05
#
# [1000 rows x 1 columns]

# %% [markdown]
# #### 2.4.3 Unificar en un solo dataframe

# %%
df_date = pd.concat([df_fecha_venta, df_fecha_ingreso])
df_date
# Out:
#          fecha
# 0   2022-01-02
# 1   2024-02-06
# 2   2024-03-26
# 3   2022-01-29
# 4   2021-06-08
# ..         ...
# 995 2023-12-16
# 996 2022-11-22
# 997 2022-08-04
# 998 2022-04-07
# 999 2022-08-05
#
# [2000 rows x 1 columns]

# %% [markdown]
# #### 2.4.4 Eliminar registros duplicados

# %%
df_date = df_date.drop_duplicates()
df_date
# Out:
#          fecha
# 0   2022-01-02
# 1   2024-02-06
# 2   2024-03-26
# 3   2022-01-29
# 4   2021-06-08
# ..         ...
# 971 2020-01-22
# 976 2022-03-26
# 979 2020-01-02
# 980 2024-03-11
# 995 2023-12-16
#
# [1120 rows x 1 columns]

# %% [markdown]
# #### 2.4.5 Crear los fields para la dimensión

# %%
df_date = df_date.copy()
df_date['año'] = pd.DatetimeIndex(df_date['fecha']).year
df_date['trimestre'] = pd.DatetimeIndex(df_date['fecha']).quarter
df_date['mes'] = pd.DatetimeIndex(df_date['fecha']).month
df_date['dia'] = pd.DatetimeIndex(df_date['fecha']).day
df_date['dia_de_la_semana'] = pd.DatetimeIndex(df_date['fecha']).dayofweek
df_date['es_fin_de_semana'] = df_date['fecha'].dt.dayofweek.apply(lambda x: 1 if x >= 5 else 0)
df_date['id_fecha'] = df_date['fecha'].astype(str).str.replace('-', '')
df_date
# Out:
#          fecha   año  trimestre  mes  dia  dia_de_la_semana  es_fin_de_semana  \
# 0   2022-01-02  2022          1    1    2                 6                 1
# 1   2024-02-06  2024          1    2    6                 1                 0
# 2   2024-03-26  2024          1    3   26                 1                 0
# 3   2022-01-29  2022          1    1   29                 5                 1
# 4   2021-06-08  2021          2    6    8                 1                 0
# ..         ...   ...        ...  ...  ...               ...               ...
# 971 2020-01-22  2020          1    1   22                 2                 0
# 976 2022-03-26  2022          1    3   26                 5                 1
# 979 2020-01-02  2020          1    1    2                 3                 0
# 980 2024-03-11  2024          1    3   11                 0                 0
# 995 2023-12-16  2023          4   12   16                 5                 1
#
#      id_fecha
# 0    20220102
# 1    20240206
# 2    20240326
# 3    20220129
# 4    20210608
# ..        ...
# 971  20200122
# 976  20220326
# 979  20200102
# 980  20240311
# 995  20231216
#
# [1120 rows x 8 columns]

# %% [markdown]
# ### 2.5 Tabla de Hechos - Ventas

# %%
query = 'SELECT * FROM detalle_venta;'
df_hecho_ventas_det = pd.read_sql(query, driver)
df_hecho_ventas_det
# Out:
#       id_detalle_venta  id_venta  id_articulo  cantidad  precio  descuento
# 0                    0       995          273        52   47.75       0.29
# 1                    1       483          685       329   55.95       0.78
# 2                    2       110          372       815   72.39       0.11
# 3                    3       312          571       293   87.07       0.47
# 4                    4        57          773       709   95.64       0.86
# ...                ...       ...          ...       ...     ...        ...
# 2995              2995       604          296       405   52.07       0.49
# 2996              2996       311          592       194   14.28       0.98
# 2997              2997       672          434         8   14.50       0.61
# 2998              2998       378          903       689   54.63       0.71
# 2999              2999       908          806        78   15.39       0.40
#
# [3000 rows x 6 columns]

# %%
query = 'SELECT id_venta, id_persona, id_usuario, fecha FROM venta;'
df_hecho_ventas = pd.read_sql(query, driver)
df_hecho_ventas
# Out:
#      id_venta  id_persona  id_usuario      fecha
# 0           0           5        1395 2022-01-02
# 1           1           8        9572 2024-02-06
# 2           2           5        1973 2024-03-26
# 3           3           8        5543 2022-01-29
# 4           4           1        4457 2021-06-08
# ..        ...         ...         ...        ...
# 995       995           8         563 2023-04-10
# 996       996           6        2250 2021-12-19
# 997       997           5        7239 2022-02-09
# 998       998           3        4264 2020-05-22
# 999       999           2        8899 2021-08-04
#
# [1000 rows x 4 columns]

# %%
fact_ventas = df_hecho_ventas_det.merge(df_hecho_ventas, on='id_venta', how='inner')
fact_ventas
# Out:
#       id_detalle_venta  id_venta  id_articulo  cantidad  precio  descuento  \
# 0                    0       995          273        52   47.75       0.29
# 1                  159       995          948       149   31.18       0.10
# 2                 2342       995          178       240   77.36       0.13
# 3                    1       483          685       329   55.95       0.78
# 4                 1188       483          987       803   38.36       0.79
# ...                ...       ...          ...       ...     ...        ...
# 2995              2887        73          314       498   47.76       0.89
# 2996              2906       287          950       382   96.01       0.60
# 2997              2941       502          623       564   76.70       0.47
# 2998              2955       554          167        13   57.66       0.85
# 2999              2974       322          949        28   75.56       0.32
#
#       id_persona  id_usuario      fecha
# 0              8         563 2023-04-10
# 1              8         563 2023-04-10
# 2              8         563 2023-04-10
# 3              3        5686 2023-05-10
# 4              3        5686 2023-05-10
# ...          ...         ...        ...
# 2995           5         852 2021-09-04
# 2996           1        7167 2020-12-13
# 2997           4        8083 2021-09-01
# 2998           3        7850 2022-06-04
# 2999           0        7435 2023-03-16
#
# [3000 rows x 9 columns]

# %% [markdown]
# #### 2.5.2 Agregar columnas computadas (impuesto, total y fecha)

# %%
fact_ventas['total'] = fact_ventas['cantidad'] * (fact_ventas['precio'] - fact_ventas['descuento'])
fact_ventas
# Out:
#       id_detalle_venta  id_venta  id_articulo  cantidad  precio  descuento  \
# 0                    0       995          273        52   47.75       0.29
# 1                  159       995          948       149   31.18       0.10
# 2                 2342       995          178       240   77.36       0.13
# 3                    1       483          685       329   55.95       0.78
# 4                 1188       483          987       803   38.36       0.79
# ...                ...       ...          ...       ...     ...        ...
# 2995              2887        73          314       498   47.76       0.89
# 2996              2906       287          950       382   96.01       0.60
# 2997              2941       502          623       564   76.70       0.47
# 2998              2955       554          167        13   57.66       0.85
# 2999              2974       322          949        28   75.56       0.32
#
#       id_persona  id_usuario      fecha     total
# 0              8         563 2023-04-10   2467.92
# 1              8         563 2023-04-10   4630.92
# 2              8         563 2023-04-10  18535.20
# 3              3        5686 2023-05-10  18150.93
# 4              3        5686 2023-05-10  30168.71
# ...          ...         ...        ...       ...
# 2995           5         852 2021-09-04  23341.26
# 2996           1        7167 2020-12-13  36446.62
# 2997           4        8083 2021-09-01  42993.72
# 2998           3        7850 2022-06-04    738.53
# 2999           0        7435 2023-03-16   2106.72
#
# [3000 rows x 10 columns]

# %%
fact_ventas['impuesto'] = fact_ventas['total'] * 0.12
fact_ventas
# Out:
#       id_detalle_venta  id_venta  id_articulo  cantidad  precio  descuento  \
# 0                    0       995          273        52   47.75       0.29
# 1                  159       995          948       149   31.18       0.10
# 2                 2342       995          178       240   77.36       0.13
# 3                    1       483          685       329   55.95       0.78
# 4                 1188       483          987       803   38.36       0.79
# ...                ...       ...          ...       ...     ...        ...
# 2995              2887        73          314       498   47.76       0.89
# 2996              2906       287          950       382   96.01       0.60
# 2997              2941       502          623       564   76.70       0.47
# 2998              2955       554          167        13   57.66       0.85
# 2999              2974       322          949        28   75.56       0.32
#
#       id_persona  id_usuario      fecha     total   impuesto
# 0              8         563 2023-04-10   2467.92   296.1504
# 1              8         563 2023-04-10   4630.92   555.7104
# 2              8         563 2023-04-10  18535.20  2224.2240
# 3              3        5686 2023-05-10  18150.93  2178.1116
# 4              3        5686 2023-05-10  30168.71  3620.2452
# ...          ...         ...        ...       ...        ...
# 2995           5         852 2021-09-04  23341.26  2800.9512
# 2996           1        7167 2020-12-13  36446.62  4373.5944
# 2997           4        8083 2021-09-01  42993.72  5159.2464
# 2998           3        7850 2022-06-04    738.53    88.6236
# 2999           0        7435 2023-03-16   2106.72   252.8064
#
# [3000 rows x 11 columns]

# %%
df_factTable = fact_ventas.copy()
df_factTable['year'] = pd.DatetimeIndex(df_factTable['fecha']).year
df_factTable['month'] = pd.DatetimeIndex(df_factTable['fecha']).month
df_factTable['day'] = pd.DatetimeIndex(df_factTable['fecha']).day
df_factTable['hour'] = pd.DatetimeIndex(df_factTable['fecha']).hour
df_factTable['minute'] = pd.DatetimeIndex(df_factTable['fecha']).minute
fact_ventas['id_fecha'] = fact_ventas['fecha'].astype(str).str.replace('-', '')


fact_ventas.head()
# Out:
#    id_detalle_venta  id_venta  id_articulo  cantidad  precio  descuento  \
# 0                 0       995          273        52   47.75       0.29
# 1               159       995          948       149   31.18       0.10
# 2              2342       995          178       240   77.36       0.13
# 3                 1       483          685       329   55.95       0.78
# 4              1188       483          987       803   38.36       0.79
#
#    id_persona  id_usuario      fecha     total   impuesto  id_fecha
# 0           8         563 2023-04-10   2467.92   296.1504  20230410
# 1           8         563 2023-04-10   4630.92   555.7104  20230410
# 2           8         563 2023-04-10  18535.20  2224.2240  20230410
# 3           3        5686 2023-05-10  18150.93  2178.1116  20230510
# 4           3        5686 2023-05-10  30168.71  3620.2452  20230510

# %%
fact_ventas = fact_ventas.drop(columns=['estado_rol'])
fact_ventas.head()

# %%
fact_ventas['id_articulo'].value_counts()
# Out:
# id_articulo
# 531    9
# 925    9
# 716    9
# 174    9
# 130    9
#       ..
# 170    1
# 591    1
# 359    1
# 432    1
# 949    1
# Name: count, Length: 938, dtype: int64

# %% [markdown]
# ### 2.6 Tabla de Hechos - Ingresos

# %%
query = 'SELECT * FROM detalle_ingreso;'
df_hecho_ingreso_det = pd.read_sql(query, driver)
df_hecho_ingreso_det
# Out:
#       id_detalle_ingreso  id_ingreso  id_articulo  cantidad  precio_unitario
# 0                      0         817          155       113            24.47
# 1                      1         772          534       425            38.95
# 2                      2          56          250       389            75.60
# 3                      3         416          531       595            23.93
# 4                      4         532          952       767            93.92
# ...                  ...         ...          ...       ...              ...
# 2995                2995         200          984       526            54.57
# 2996                2996         686           35       218            81.29
# 2997                2997         818          253       602            21.87
# 2998                2998         432          491       249            71.64
# 2999                2999         504          122       154            79.88
#
# [3000 rows x 5 columns]

# %%
query = 'SELECT id_ingreso, id_proveedor, id_usuario, fecha FROM ingreso;'
df_hecho_ingreso = pd.read_sql(query, driver)
df_hecho_ingreso
# Out:
#      id_ingreso  id_proveedor  id_usuario      fecha
# 0             0             3        4808 2020-02-13
# 1             1             7        8855 2024-02-09
# 2             2             7        6980 2022-05-17
# 3             3             2        9179 2022-10-27
# 4             4             4        8155 2022-12-21
# ..          ...           ...         ...        ...
# 995         995             7        1624 2023-12-16
# 996         996             7        1965 2022-11-22
# 997         997             9        4704 2022-08-04
# 998         998             2        4117 2022-04-07
# 999         999             8        1774 2022-08-05
#
# [1000 rows x 4 columns]

# %%
fact_ingresos = df_hecho_ingreso_det.merge(df_hecho_ingreso, on='id_ingreso', how='inner')
fact_ingresos
# Out:
#       id_detalle_ingreso  id_ingreso  id_articulo  cantidad  precio_unitario  \
# 0                      0         817          155       113            24.47
# 1                     91         817           15       674            71.85
# 2                   1587         817          419       689            41.60
# 3                   2935         817          717       194            33.75
# 4                      1         772          534       425            38.95
# ...                  ...         ...          ...       ...              ...
# 2995                2926         113          107       542            34.85
# 2996                2947         444           76       765            74.01
# 2997                2949         811          680         4            91.33
# 2998                2955         476          652       584            43.24
# 2999                2988         892          694       797            81.12
#
#       id_proveedor  id_usuario      fecha
# 0                7        9916 2022-12-28
# 1                7        9916 2022-12-28
# 2                7        9916 2022-12-28
# 3                7        9916 2022-12-28
# 4                9        8011 2022-04-10
# ...            ...         ...        ...
# 2995             1        4296 2023-09-29
# 2996             8        5809 2020-08-15
# 2997             2        9962 2020-03-29
# 2998             6        6772 2022-12-25
# 2999             8        3744 2023-01-23
#
# [3000 rows x 8 columns]

# %% [markdown]
# #### 2.6.2 Agregar columnas computadas (total y id_fecha)

# %%
fact_ingresos['total'] = fact_ingresos['cantidad'] * fact_ingresos['precio_unitario']
fact_ingresos
# Out:
#       id_detalle_ingreso  id_ingreso  id_articulo  cantidad  precio_unitario  \
# 0                      0         817          155       113            24.47
# 1                     91         817           15       674            71.85
# 2                   1587         817          419       689            41.60
# 3                   2935         817          717       194            33.75
# 4                      1         772          534       425            38.95
# ...                  ...         ...          ...       ...              ...
# 2995                2926         113          107       542            34.85
# 2996                2947         444           76       765            74.01
# 2997                2949         811          680         4            91.33
# 2998                2955         476          652       584            43.24
# 2999                2988         892          694       797            81.12
#
#       id_proveedor  id_usuario      fecha     total
# 0                7        9916 2022-12-28   2765.11
# 1                7        9916 2022-12-28  48426.90
# 2                7        9916 2022-12-28  28662.40
# 3                7        9916 2022-12-28   6547.50
# 4                9        8011 2022-04-10  16553.75
# ...            ...         ...        ...       ...
# 2995             1        4296 2023-09-29  18888.70
# 2996             8        5809 2020-08-15  56617.65
# 2997             2        9962 2020-03-29    365.32
# 2998             6        6772 2022-12-25  25252.16
# 2999             8        3744 2023-01-23  64652.64
#
# [3000 rows x 9 columns]

# %%
df_factTable2 = fact_ingresos.copy()
df_factTable2['year'] = pd.DatetimeIndex(df_factTable2['fecha']).year
df_factTable2['month'] = pd.DatetimeIndex(df_factTable2['fecha']).month
df_factTable2['day'] = pd.DatetimeIndex(df_factTable2['fecha']).day
df_factTable2['hour'] = pd.DatetimeIndex(df_factTable2['fecha']).hour
df_factTable2['minute'] = pd.DatetimeIndex(df_factTable2['fecha']).minute
fact_ingresos['id_fecha'] = fact_ingresos['fecha'].astype(str).str.replace('-', '')


fact_ingresos.head()
# Out:
#    id_detalle_ingreso  id_ingreso  id_articulo  cantidad  precio_unitario  \
# 0                   0         817          155       113            24.47
# 1                  91         817           15       674            71.85
# 2                1587         817          419       689            41.60
# 3                2935         817          717       194            33.75
# 4                   1         772          534       425            38.95
#
#    id_proveedor  id_usuario      fecha     total  id_fecha
# 0             7        9916 2022-12-28   2765.11  20221228
# 1             7        9916 2022-12-28  48426.90  20221228
# 2             7        9916 2022-12-28  28662.40  20221228
# 3             7        9916 2022-12-28   6547.50  20221228
# 4             9        8011 2022-04-10  16553.75  20220410

# %% [markdown]
# ### 3.1 Hacemos configuración inicial

# %%
config = configparser.ConfigParser()
config.read('config2.cfg')
# Out:
# ['config2.cfg']

# %%
aws_rds_conn = boto3.client('rds', aws_access_key_id = config.get('IAM', 'ACCESS_KEY'), 
                              aws_secret_access_key = config.get('IAM', 'SECRET_ACCESS_KEY'),
                              region_name = 'us-east-1')

# %%
rds_instances_ids = []
aws_response = aws_rds_conn.describe_db_instances()

for response in aws_response['DBInstances']:
    rds_instances_ids.append(response['DBInstanceIdentifier'])

print(f'Instancias Disponibles: {rds_instances_ids}')
# Out:
# Instancias Disponibles: ['e-dreams-dwh']

# %% [markdown]
# ### 3.2 Creamos instancia de base de datos en AWS - mySQL

# %%
try:
    response = aws_rds_conn.create_db_instance(
            DBInstanceIdentifier = config.get('DWH', 'DWH_INSTANCE_ID'),
            DBName = config.get('DWH', 'DWH_NAME'),
            DBInstanceClass = 'db.t3.micro',
            Engine = 'mysql',
            MasterUsername = config.get('DWH', 'DWH_USER'),
            MasterUserPassword = config.get('DWH', 'DWH_PASSWORD'),
            Port = int(config.get('DWH', 'DWH_PORT')),
            PubliclyAccessible = True,
            VpcSecurityGroupIds = [config.get('VPC', 'SECURITY_GROUP')],
            AllocatedStorage = 15
        )
    print(response)
except aws_rds_conn.exceptions.DBInstanceAlreadyExistsFault as ex:
    print('La instancia ya existe')
except Exception as ex:
    print('Error!', ex)
# Out:
# La instancia ya existe

# %%
try:

    instance = aws_rds_conn.describe_db_instances(DBInstanceIdentifier = config.get('DWH', 'DWH_INSTANCE_ID'))
    RDS_HOSTNAME = instance.get('DBInstances')[0].get('Endpoint').get('Address')
    print(RDS_HOSTNAME)

except Exception as ex:
    print('Error!!!', ex)
# Out:
# e-dreams-dwh.ch62gk4wowqh.us-east-1.rds.amazonaws.com

# %%
# Delete the DB instance
#response = aws_rds_conn.delete_db_instance(
#    DBInstanceIdentifier=config.get('DWH', 'DWH_INSTANCE_ID'),
#    SkipFinalSnapshot=True  # Set to False if you want to take a final snapshot
#)

# %%
try:

    instance = aws_rds_conn.describe_db_instances(DBInstanceIdentifier = config.get('DWH', 'DWH_INSTANCE_ID'))
    RDS_HOSTNAME = instance.get('DBInstances')[0].get('Endpoint').get('Address')
    print(RDS_HOSTNAME)

except Exception as ex:
    print('Error!!!', ex)
# Out:
# e-dreams-dwh.ch62gk4wowqh.us-east-1.rds.amazonaws.com

# %% [markdown]
# ### 3.3 Creamos la bd para el DWH

# %%
# pip install mysql-connector-python
# pip install pymysql
import mysql.connector

# %%
import sql_queries_2
sql_queries_2.DDL_QUERY
# Out:
# '\nCREATE TABLE IF NOT EXISTS dim_articulo (\n    id_articulo INT,\n\tid_categoria INT,\n    codigo VARCHAR(50),\n    nombre VARCHAR(100),\n    precio_venta NUMERIC(11,2),\n    descripcion VARCHAR(255),\n    imagen VARCHAR(20),\n    nombre_categoria VARCHAR(50),\n    descripcion_categoria VARCHAR(255),\n    \n    PRIMARY KEY (id_articulo)\n);\n\nCREATE TABLE IF NOT EXISTS dim_persona (\n    id_persona INT,\n\ttipo_persona VARCHAR(20),\n    nombre VARCHAR(100),\n    tipo_documento VARCHAR(20),\n    num_documento VARCHAR(20),\n    direccion VARCHAR(20),\n    telefono VARCHAR(20),\n    email VARCHAR(20),\n    \n    PRIMARY KEY (id_persona)\n);\n\nCREATE TABLE IF NOT EXISTS dim_usuario (\n    id_usuario INT,\n\tid_rol INT,\n    nombre VARCHAR(100),\n    tipo_documento VARCHAR(20),\n    num_documento VARCHAR(20),\n    direccion VARCHAR(20),\n    telefono VARCHAR(20),\n    email VARCHAR(20),\n    clave BLOB ,\n    nombre_rol VARCHAR(30),\n    descripcion_rol VARCHAR(30),\n    \n    PRIMARY KEY (id_usuario)\n);\n\n\nCREATE TABLE IF NOT EXISTS dim_fecha (\n\tfecha DATE, \n    año TINYINT,\n\ttrimestre TINYINT,\n    mes TINYINT,\n    dia TINYINT,\n    dia_de_la_semana TINYINT,\n    es_fin_de_semana TINYINT,\n    id_fecha INT,\n    \n    PRIMARY KEY (id_fecha)\n);\n\nCREATE TABLE IF NOT EXISTS fact_ventas (\n\tsk_fact_ventas INT AUTO_INCREMENT, \n\tid_detalle_venta INT,\n    id_venta INT,\n    id_articulo INT REFERENCES dim_articulo(id_articulo),\n    id_fecha INT REFERENCES dim_fecha(id_fecha),\n    cantidad TINYINT,\n    precio NUMERIC(11,2),\n    descuento NUMERIC(11,2),\n    id_persona INT REFERENCES dim_persona(id_persona),\n    id_usuario INT REFERENCES dim_usuario(id_usuario),\n    total NUMERIC(11,2),\n    impuesto FLOAT,\n    \n    PRIMARY KEY (sk_fact_ventas)\n);\n\nCREATE TABLE IF NOT EXISTS fact_ingresos (\n\tsk_fact_ingresos INT AUTO_INCREMENT, \n\tid_detalle_ingreso INT,\n    id_ingreso INT,\n    id_articulo INT REFERENCES dim_articulo(id_articulo),\n    id_fecha INT REFERENCES dim_fecha(id_fecha),\n    cantidad TINYINT,\n    precio_unitario NUMERIC(11,2),\n    id_proveedor INT REFERENCES dim_persona(id_persona),\n    id_usuario INT REFERENCES dim_usuario(id_usuario),\n    total NUMERIC(11,2),\n    \n    PRIMARY KEY (sk_fact_ingresos)\n);\n\n'

# %%
try:
    db_sql_conn = mysql.connector.connect(
        database=config.get('DWH', 'DWH_NAME'),
        user=config.get('DWH', 'DWH_USER'),
        password=config.get('DWH', 'DWH_PASSWORD'),
        host=RDS_HOSTNAME,
        port=int(config.get('DWH', 'DWH_PORT'))
    )
    cursor = db_sql_conn.cursor()
    cursor.execute(sql_queries_2.DDL_QUERY, multi=True)
    db_sql_conn.commit()
    cursor.close()
    print('Base de Datos Creada Exitosamente')

except Exception as ex:
    print('Error!!!', ex)
# Out:
# Error!!! Commands out of sync; you can't run this command now

# %%
mysql_driver = f"""mysql+pymysql://{config.get('DWH', 'DWH_USER')}:{config.get('DWH', 'DWH_PASSWORD')}@{RDS_HOSTNAME}:{config.get('DWH', 'DWH_PORT')}/{config.get('DWH', 'DWH_NAME')}"""

# %% [markdown]
# ### 3.4 Poblar las dimensiones

# %%
dim_articulo.to_sql('dim_articulo', mysql_driver, index=False, if_exists='append')
# Out:
# 1000

# %%
dim_personas.to_sql('dim_persona', mysql_driver, index=False, if_exists='append')
# Out:
# 10

# %%
dim_usuario.to_sql('dim_usuario', mysql_driver, index=False, if_exists='append')
# Out:
# 10000

# %%
df_date.to_sql('dim_fecha', mysql_driver, index=False, if_exists='append')
# Out:
# 1120

# %%
fact_ventas.to_sql('fact_ventas', mysql_driver, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'fecha' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 fact_ventas.to_sql('fact_ventas', mysql_driver, index=False, if_exists='append')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:332, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     328 def _execute_on_connection(
#     329     self, connection, multiparams, params, execution_options, _force=False
#     330 ):
#     331     if _force or self.supports_execution:
# --> 332         return connection._execute_clauseelement(
#     333             self, multiparams, params, execution_options
#     334         )
#     335     else:
#     336         raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                 break
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#    1803     if self.dialect._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#     195         context._rowcount = rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     180     q_postfix = m.group(3) or ""
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     192 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     218         sql += b","
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#     222 return rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column 'fecha' in 'field list'")
# [SQL: INSERT INTO fact_ventas (id_detalle_venta, id_venta, id_articulo, cantidad, precio, descuento, id_persona, id_usuario, fecha, total, impuesto, id_fecha) VALUES (%(id_detalle_venta)s, %(id_venta)s, %(id_articulo)s, %(cantidad)s, %(precio)s, %(descuento)s, %(id_persona)s, %(id_usuario)s, %(fecha)s, %(total)s, %(impuesto)s, %(id_fecha)s)]
# [parameters: ({'id_detalle_venta': 0, 'id_venta': 995, 'id_articulo': 273, 'cantidad': 52, 'precio': 47.75, 'descuento': 0.29, 'id_persona': 8, 'id_usuario': 563, 'fecha': datetime.datetime(2023, 4, 10, 0, 0), 'total': 2467.92, 'impuesto': 296.1504, 'id_fecha': '20230410'}, {'id_detalle_venta': 159, 'id_venta': 995, 'id_articulo': 948, 'cantidad': 149, 'precio': 31.18, 'descuento': 0.1, 'id_persona': 8, 'id_usuario': 563, 'fecha': datetime.datetime(2023, 4, 10, 0, 0), 'total': 4630.92, 'impuesto': 555.7103999999999, 'id_fecha': '20230410'}, {'id_detalle_venta': 2342, 'id_venta': 995, 'id_articulo': 178, 'cantidad': 240, 'precio': 77.36, 'descuento': 0.13, 'id_persona': 8, 'id_usuario': 563, 'fecha': datetime.datetime(2023, 4, 10, 0, 0), 'total': 18535.2, 'impuesto': 2224.224, 'id_fecha': '20230410'}, {'id_detalle_venta': 1, 'id_venta': 483, 'id_articulo': 685, 'cantidad': 329, 'precio': 55.95, 'descuento': 0.78, 'id_persona': 3, 'id_usuario': 5686, 'fecha': datetime.datetime(2023, 5, 10, 0, 0), 'total': 18150.93, 'impuesto': 2178.1116, 'id_fecha': '20230510'}, {'id_detalle_venta': 1188, 'id_venta': 483, 'id_articulo': 987, 'cantidad': 803, 'precio': 38.36, 'descuento': 0.79, 'id_persona': 3, 'id_usuario': 5686, 'fecha': datetime.datetime(2023, 5, 10, 0, 0), 'total': 30168.71, 'impuesto': 3620.2452, 'id_fecha': '20230510'}, {'id_detalle_venta': 2408, 'id_venta': 483, 'id_articulo': 989, 'cantidad': 440, 'precio': 67.18, 'descuento': 0.28, 'id_persona': 3, 'id_usuario': 5686, 'fecha': datetime.datetime(2023, 5, 10, 0, 0), 'total': 29436.000000000004, 'impuesto': 3532.32, 'id_fecha': '20230510'}, {'id_detalle_venta': 2815, 'id_venta': 483, 'id_articulo': 647, 'cantidad': 284, 'precio': 58.9, 'descuento': 0.35, 'id_persona': 3, 'id_usuario': 5686, 'fecha': datetime.datetime(2023, 5, 10, 0, 0), 'total': 16628.2, 'impuesto': 1995.384, 'id_fecha': '20230510'}, {'id_detalle_venta': 2928, 'id_venta': 483, 'id_articulo': 342, 'cantidad': 64, 'precio': 87.11, 'descuento': 0.81, 'id_persona': 3, 'id_usuario': 5686, 'fecha': datetime.datetime(2023, 5, 10, 0, 0), 'total': 5523.2, 'impuesto': 662.784, 'id_fecha': '20230510'}  ... displaying 10 of 3000 total bound parameter sets ...  {'id_detalle_venta': 2955, 'id_venta': 554, 'id_articulo': 167, 'cantidad': 13, 'precio': 57.66, 'descuento': 0.85, 'id_persona': 3, 'id_usuario': 7850, 'fecha': datetime.datetime(2022, 6, 4, 0, 0), 'total': 738.53, 'impuesto': 88.6236, 'id_fecha': '20220604'}, {'id_detalle_venta': 2974, 'id_venta': 322, 'id_articulo': 949, 'cantidad': 28, 'precio': 75.56, 'descuento': 0.32, 'id_persona': 0, 'id_usuario': 7435, 'fecha': datetime.datetime(2023, 3, 16, 0, 0), 'total': 2106.7200000000003, 'impuesto': 252.80640000000002, 'id_fecha': '20230316'})]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
